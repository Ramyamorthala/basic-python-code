# %%
import numpy as np
import pandas as pd

# %%
movies = pd.read_csv(r"C:\Users\RAMYA\Downloads\Movie-Rating.csv")

# %%
movies
# Out:
#                       Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer      Comedy                         87
# 1              10,000 B.C.  Adventure                          9
# 2               12 Rounds      Action                         30
# 3                127 Hours  Adventure                         93
# 4                17 Again      Comedy                         55
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                         26
# 555        Youth in Revolt     Comedy                         68
# 556                 Zodiac   Thriller                         89
# 557            Zombieland      Action                         90
# 558              Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# 1                    44                 105             2008
# ...

# %%
id(movies)
# Out:
# 2724149710192

# %%
movies.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movies.tail()
# Out:
#                 Film     Genre  Rotten Tomatoes Ratings %  Audience Ratings %  \
# 554    Your Highness    Comedy                         26                  36
# 555  Youth in Revolt    Comedy                         68                  52
# 556           Zodiac  Thriller                         89                  73
# 557      Zombieland     Action                         90                  87
# 558        Zookeeper    Comedy                         14                  42
#
#      Budget (million $)  Year of release
# 554                  50             2011
# 555                  18             2009
# 556                  65             2007
# 557                  24             2009
# 558                  80             2011

# %%
movies.shape
# Out:
# (559, 6)

# %%
len(movies)
# Out:
# 559

# %%
movies.info() # no null values and the dataset is clean, hence no need for datacleansing
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Film                       559 non-null    object
#  1   Genre                      559 non-null    object
#  2   Rotten Tomatoes Ratings %  559 non-null    int64
#  3   Audience Ratings %         559 non-null    int64
#  4   Budget (million $)         559 non-null    int64
#  5   Year of release            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies.columns = ['Film','Genre' , 'Critic rating' , 'Audience rating' , 'Budgetmillions' , 'Year']

# %%
movies.columns #removed all the unnecessary charecters and understanble words
# Out:
# Index(['Film', 'Genre', 'Critic rating', 'Audience rating', 'Budgetmillions',
#        'Year'],
#       dtype='object')

# %%
movies.describe()
# Out:
#        Critic rating  Audience rating  Budgetmillions         Year
# count     559.000000       559.000000      559.000000   559.000000
# mean       47.309481        58.744186       50.236136  2009.152057
# std        26.413091        16.826887       48.731817     1.362632
# min         0.000000         0.000000        0.000000  2007.000000
# 25%        25.000000        47.000000       20.000000  2008.000000
# 50%        46.000000        58.000000       35.000000  2009.000000
# 75%        70.000000        72.000000       65.000000  2010.000000
# max        97.000000        96.000000      300.000000  2011.000000

# %%
movies.describe().transpose()
# Out:
#                  count         mean        std     min     25%     50%  \
# Critic rating    559.0    47.309481  26.413091     0.0    25.0    46.0
# Audience rating  559.0    58.744186  16.826887     0.0    47.0    58.0
# Budgetmillions   559.0    50.236136  48.731817     0.0    20.0    35.0
# Year             559.0  2009.152057   1.362632  2007.0  2008.0  2009.0
#
#                     75%     max
# Critic rating      70.0    97.0
# Audience rating    72.0    96.0
# Budgetmillions     65.0   300.0
# Year             2010.0  2011.0

# %%
movies['Film'] = movies['Film'].astype('category')
movies.Genre = movies.Genre.astype('category')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Film             559 non-null    category
#  1   Genre            559 non-null    category
#  2   Critic rating    559 non-null    int64
#  3   Audience rating  559 non-null    int64
#  4   Budgetmillions   559 non-null    int64
#  5   Year             559 non-null    int64
# dtypes: category(2), int64(4)
# memory usage: 40.1 KB

# %%
from matplotlib import pyplot as plt # for visualization
import seaborn as sns #for advanced vis /statistical visualization

# %matplotlib inline 

import warnings
warnings.filterwarnings('ignore')

# %%
vis = sns.jointplot(data = movies, x = 'Critic rating' , y = 'Audience rating')
plt.show()
# Audience rating is more dominant then critics rating
# Based on this we find out as most people are most liklihood to watch audience rating & less likely to wathc critics rating
# let me explain the excel - if you filter audience rating & critic rating. critic rating has very low values compare to audience rating

# %%
vis = sns.jointplot(data = movies, x = 'Critic rating' , y = 'Audience rating',kind = 'scatter')
plt.show()

# %%
vis = sns.jointplot(data = movies, x = 'Critic rating' , y = 'Audience rating',kind = 'reg')
plt.show()

# %%
vis = sns.jointplot(data = movies, x = 'Critic rating' , y = 'Audience rating',kind = 'hex') # kind helps in plotting the graph differnt types
plt.show()

# %%
vis = sns.jointplot(data = movies, x = 'Critic rating' , y = 'Audience rating',kind = 'kde' ,cmap = 'Greens') #kde= kernel density plots
plt.show()

# %%
plt.hist(movies.Budgetmillions) #univaritae analysis
plt.show()

# %%
graph = sns.lmplot(data = movies , x ='Critic rating', y = 'Audience rating' ,
                   hue = 'Genre' , fit_reg = False)
plt.show() #hue helps in identifing the speicific catergory

# %%
graph = sns.lmplot(data = movies , x = 'Critic rating', y = 'Audience rating' , fit_reg = True , hue = 'Genre')
plt.show()

# %%
b = sns.boxplot(data = movies , x = 'Genre' , y = 'Critic rating', hue= 'Genre')
plt.show()

# %%
v = sns.violinplot(data = movies , x = 'Genre' , y = 'Critic rating',hue = 'Genre')
plt.show()

# %%
D = sns.boxplot(data = movies[movies.Genre == 'Drama'] , x = 'Year' , y = 'Audience rating')
plt.show()

# %%
#Facetgrid (#multivariate analysis)

g = sns.FacetGrid(movies , row = 'Genre' , col = 'Year' , hue = 'Genre')
plt.show()

# %%
#so to fill the facetgrids , we need to use map function and hence maps are plotted in the graph


g = sns.FacetGrid(movies , row = 'Genre' , col = 'Year' , hue = 'Genre')
g = g.map(plt.scatter , 'Critic rating' ,'Audience rating')
plt.show()                               #with map function, scatterplots are mapped in facetgrids

# %%
F = sns.FacetGrid(movies , row = 'Genre' , col = 'Year' , hue = 'Genre')
F = F.map(plt.hist , 'Budgetmillions') #histograms are mapped in facetgrids
plt.show()
